# %%
import requests
import bs4
import urllib.parse
import IPython.display
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from IPython.display import Image, display


section_dict = {
    '최신뉴스':'n0100',
    '정치':'n0200',
    '경제':'n0300',
    '사회':'n0400',    
    '세계':'n0500',
    'IT/과학':'n0600',
    }


def print_news(section_name):
    # IT/과학 뉴스
    print('print_news(\'{}\')'.format(section_name))
    section = section_dict[section_name]
    # req_param = section_name
    #
    if section == "n0100":
        url = "https://news.nate.com/recent?mid={}".format(section)
        print(f"=====> {url} {section_name} 뉴스 <=====")
        
    else :
        url = "https://news.nate.com/section?mid={}".format(section)
        print(f"=====> {url} {section_name} 뉴스 <=====")
        
    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36"
    }

    # requests 의 get() 함수 호출하기
    res = requests.get(url, headers=req_header)
    # res.encoding = "utf-8"
    
    # 응답(response)이 OK 이면
    if res.ok:
        html = res.text
        soup = BeautifulSoup(html, "html.parser")
        div_tag_list = soup.select("div.mlt01")
        for div_tag in div_tag_list:
            a_tag = div_tag.find("a")
            link = a_tag["href"]

            h2_tag = div_tag.select_one("h2.tit")
            title = h2_tag.text.strip()
            
            
            img_tag = div_tag.select_one("img")
            img_url = img_tag["src"]
            base_url = "https://..."
            full_url = urljoin(base_url, img_url)
            link_url = urljoin(base_url, link)
            if img_url is None:
                print(link_url, title)
            else:
                img = Image(full_url)
                display(img)
                print(link_url, title)
                
    else:
        # 응답(response)이 Error 이면 status code 출력
        print(f"Error code = {res.status_code}")

# %%
print_news('경제')
# Out:
# print_news('경제')
# =====> https://news.nate.com/section?mid=n0300 경제 뉴스 <=====
# https://news.nate.com/view/20250409n22190?mid=n0300 미 상호관세 발효되자 코스피 2300선 붕괴…환율 1500원 '초읽기'
# https://news.nate.com/view/20250409n25602?mid=n0300 환율급등·상호관세 '더블악재'에 산업계 비상…유례없어 대응막막
# https://news.nate.com/view/20250409n27696?mid=n0300 "7년째 적자" 현대免, 5년차 이상 직원 희망퇴직 단행
# https://news.nate.com/view/20250409n22812?mid=n0300 주요 은행장 "기업 대출 위험 낮추고, 가상자산 거래 협업 확대 필요"
# https://news.nate.com/view/20250409n22258?mid=n0300 '자영업자 폐업 속출'에 새출발기금 신청자 12만명 육박
# https://news.nate.com/view/20250409n18135?mid=n0300 금융당국 "이달 가계대출 분수령…토허제 풍선효과 면밀 점검"
# https://news.nate.com/view/20250409n17615?mid=n0300 "끼니 때우기도 어려워요"…곡소리 나는 유학생들, 원화값 폭락에 멘붕
# https://news.nate.com/view/20250409n12981?mid=n0300 "입금 먼저"vs"못 믿겠다"…홈플러스, 이번엔 입점업체와 기싸움
# https://news.nate.com/view/20250409n01699?mid=n0300 "서울 집값, 당분간 관망세…대선 이후 강남·용산 등 오른다"
# https://news.nate.com/view/20250409n02718?mid=n0300 "우리는 못 받는거 아냐?" 시한부 국민연금…이것 도입땐 16년 수명연장
# https://news.nate.com/view/20250409n08787?mid=n0300 "소비 줄여도 이건 못참지"…1인당 월 10만원 썼다
# https://news.nate.com/view/20250409n07454?mid=n0300 3월 취업자 19.3만명↑…청년 고용률 4년만에 최저, '쉬었음' 역대 최대(종합)
# https://news.nate.com/view/20250409n03870?mid=n0300 [단독] 도리토스보다 4배 비싼 '김 과자'…"다 망할 판" 탄식
# https://news.nate.com/view/20250409n01232?mid=n0300 '부산 최대어' 분담금만 9억?…"거의 집 한채 값" 전국이 비명
# https://news.nate.com/view/20250409n01699?mid=n0300 "서울 집값, 당분간 관망세…대선 이후 강남·용산 등 오른다"
